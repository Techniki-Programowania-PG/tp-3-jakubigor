# %% [markdown]
# # TECHNIKI PROGRAMOWANIA - projekt 3
#
# Jakub Trzeciak s203741
#
# Igor Wojciechowski s203281

# %%
import a3
from IPython.display import Image

# %% [markdown]
# # Wizualizacja sygnału z wykorzystaniem biblioteki matplotplusplus

# %%
a = a3.cos(2, 0, 10, 100)
b = a3.sin(0.5, 0, 10, 100)
c = a3.square(1, 0, 10, 100)
d = a3.sawtooth(1, 0, 10, 100)

# %%
a3.plot(a)
Image(filename='plot.png')

# %% [markdown]
# # DFT i transformata odwrotna

# %%
a3.cplot(a3.dft(a))
Image(filename='plot.png')

# %%
a3.plot(a3.idft(a3.dft(a)))
Image(filename='plot.png')

# %% [markdown]
# # Filtracja 1D i 2D

# %%
a3.plot(a3.filter1d(a, 0.01))
Image(filename='plot.png')

# %%
a3.cplot(a3.filter2d(a3.dft(b), 3))
Image(filename='plot.png')

# %% [markdown]
# # Generowanie sygnałów o zadanej częstotliwości (sin, cos, prostokątny, piłokształtny)

# %%
a3.plot(a)
Image(filename='plot.png')

# %%
a3.plot(b)
Image(filename='plot.png')

# %%
a3.plot(c)
Image(filename='plot.png')

# %%
a3.plot(d)
Image(filename='plot.png')

# %% [markdown]
# # Wykrywanie krawędzi (korzystajac z filtraci)

# %%
a3.cplot(a3.edge(a3.dft(c)))
Image(filename='plot.png')
